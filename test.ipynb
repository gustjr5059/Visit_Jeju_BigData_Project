# %%
import pandas as pd

# 데이터 파일 불러오기
data = pd.read_csv('주요관광지점 입장객 2022년.csv')

# '총계' 열을 기준으로 내림차순 정렬
sorted_data = data.sort_values(by='총계', ascending=False)

# 정렬된 데이터를 출력
print(sorted_data)
# Out:
#          시도    군구          관광지      총계
# 32  제주특별자치도  서귀포시        천지연폭포  998867
# 30  제주특별자치도  서귀포시  중문대포해안주상절리대  888211
# 4   제주특별자치도   제주시          비자림  876050
# 13  제주특별자치도   제주시      한라산국립공원  850744
# 24  제주특별자치도  서귀포시        성산일출봉  818803
# 27  제주특별자치도  서귀포시         정방폭포  682043
# 6   제주특별자치도   제주시      절물자연휴양림  595266
# 20  제주특별자치도  서귀포시          산방산  557162
# 2   제주특별자치도   제주시       만장굴관광지  536478
# 33  제주특별자치도  서귀포시        카멜리아힐  450465
# 34  제주특별자치도  서귀포시   한화아쿠아플라넷제주  431978
# 31  제주특별자치도  서귀포시        천제연폭포  426372
# 18  제주특별자치도  서귀포시     마라해양도립공원  375213
# 0   제주특별자치도   제주시      국립제주박물관  260556
# 8   제주특별자치도   제주시      제주돌문화공원  195163
# 22  제주특별자치도  서귀포시     서귀포자연휴양림  162667
# 3   제주특별자치도   제주시     민속자연사박물관  147177
# 25  제주특별자치도  서귀포시       이중섭미술관  137902
# 12  제주특별자치도   제주시      제주현대미술관  131388
# 15  제주특별자치도   제주시       해녀 박물관  123214
# 19  제주특별자치도  서귀포시     박물관은살아있다  114030
# 14  제주특별자치도   제주시       항몽 유적지   86931
# 7   제주특별자치도   제주시  제주도립 김창열미술관   81150
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# 사용 가능한 폰트 리스트 출력
font_list = fm.findSystemFonts(fontpaths=None, fontext='ttf')

# 사용할 한글 폰트 경로 찾기 (예: 'NanumBarunGothic')
# 이 부분은 사용자의 시스템에 따라 달라질 수 있습니다.
# 아래 코드는 'Nanum'이라는 단어가 들어간 폰트를 찾습니다. 다른 폰트를 사용하려면 이름을 변경하세요.
korean_font = [f for f in font_list if 'Nanum' in f]
print(korean_font)  # 사용 가능한 한글 폰트 출력

# Matplotlib의 기본 폰트를 한글 폰트로 설정
plt.rcParams['font.family'] = 'NanumBarunGothic'
# Out:
# []

# %%
pip install scipy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas matplotli

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.signal import find_peaks

# 데이터 파일 불러오기
# 파일 경로를 데이터 파일의 실제 위치로 변경하십시오.
data = pd.read_csv('주요관광지점 입장객 2022년.csv')

# '총계' 열을 기준으로 내림차순 정렬
sorted_data = data.sort_values(by='총계', ascending=False)

# 변곡점 찾기
visitor_counts = np.array(sorted_data['총계'])
peaks, _ = find_peaks(visitor_counts, distance=1)

# 변곡점을 표시하기 위한 준비
peak_values = visitor_counts[peaks]
peak_names = sorted_data['관광지'].iloc[peaks]

# 한글 폰트 설정
plt.rcParams['font.family'] = 'NanumBarunGothic'

# 막대 그래프와 함께 변곡점 표시
plt.figure(figsize=(10, 8))
plt.bar(sorted_data['관광지'], sorted_data['총계'], color='skyblue')
plt.scatter(peak_names, peak_values, color='red', s=100, zorder=2)  # 변곡점 표시
plt.xlabel('관광지')
plt.ylabel('총계')
plt.title('2022년 관광지별 입장객 수와 변곡점')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
# Out:
# findfont: Font family 'NanumBarunGothic' not found.
# findfont: Font family 'NanumBarunGothic' not found.
# C:\Users\it\AppData\Local\Temp\ipykernel_15596\4170515660.py:32: UserWarning: Glyph 52380 (\N{HANGUL SYLLABLE CEON}) missing from current font.
#   plt.tight_layout()
# C:\Users\it\AppData\Local\Temp\ipykernel_15596\4170515660.py:32: UserWarning: Glyph 51648 (\N{HANGUL SYLLABLE JI}) missing from current font.
#   plt.tight_layout()
# C:\Users\it\AppData\Local\Temp\ipykernel_15596\4170515660.py:32: UserWarning: Glyph 50672 (\N{HANGUL SYLLABLE YEON}) missing from current font.
#   plt.tight_layout()
# C:\Users\it\AppData\Local\Temp\ipykernel_15596\4170515660.py:32: UserWarning: Glyph 54253 (\N{HANGUL SYLLABLE POG}) missing from current font.
#   plt.tight_layout()
# C:\Users\it\AppData\Local\Temp\ipykernel_15596\4170515660.py:32: UserWarning: Glyph 54252 (\N{HANGUL SYLLABLE PO}) missing from current font.
#   plt.tight_layout()
# ...

# %%
pip install folium
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import folium

data = pd.read_csv('주요관광지점 입장객 2020~2022년_v1.csv')

# 위도와 경도를 가져옴
latitude = data.iloc[:, 4]
longitude = data.iloc[:, 5]
names = data.iloc[:, 2]

# 지도 생성 (초기 위치는 첫 번째 관광지의 위치로 설정)
m = folium.Map(location=[latitude[0], longitude[0]], zoom_start=10)

# 관광지 위치에 마커 추가
for lat, lon, name in zip(latitude, longitude, names):
    folium.Marker([lat, lon], popup=name).add_to(m)

# 지도 표시
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import matplotlib.font_manager as fm

font_path = 'C:/Users/it/Downloads/nanum-all/나눔 글꼴/나눔바른고딕/NanumFontSetup_TTF_BARUNGOTHIC/NanumBarunGothic.ttf'
font_prop = fm.FontProperties(fname=font_path)

# 파일 경로 설정
file_path = 'C:/Visit_Jeju_BigData_Project/제주 여행 패턴 조사.xlsx'

# 엑셀 파일 읽기
jeju_travel_data = pd.read_excel(file_path)

# 분석할 열 선택 (C열부터 Q열까지)
columns_to_analyze = jeju_travel_data.columns[2:17]

# 선택된 열의 데이터 필터링
filtered_data = jeju_travel_data[columns_to_analyze]

# 문자열 데이터를 수치형 데이터로 변환하는 함수 (수정된 버전)
def convert_to_numerical_v2(value):
    try:
        if isinstance(value, str):
            if ':' in value:  # 시간 값 (예: '10:00')
                hours, minutes = value.split(':')
                return float(hours) + float(minutes) / 60
            elif '시간' in value and '분' in value:  # 지속 시간 (예: '1시간 30분')
                hours, minutes = value.replace('시간', '').replace('분', '').split()
                return float(hours) + float(minutes) / 60
            elif '시간' in value:  # 지속 시간 (예: '1시간')
                return float(value.replace('시간', '').strip())
            elif '곳' in value:  # 횟수 값 (예: '2곳')
                return float(value.replace('곳', '').strip())
            elif '끼' in value:  # 식사 횟수 (예: '3끼')
                return float(value.replace('끼', '').strip())
            elif '분' in value:  # 분 단위 시간 (예: '30분')
                return float(value.replace('분', '').strip()) / 60
        return float(value)
    except ValueError:
        return None

# 수정된 함수를 적용하여 데이터 변환
numerical_data_v2 = filtered_data.applymap(convert_to_numerical_v2)

# 유효한 수치 데이터만 추출
valid_numerical_data_v2 = numerical_data_v2.dropna(how='all', axis=1)

# 유효한 데이터의 상관관계 매트릭스 계산
correlation_matrix_valid_v2 = valid_numerical_data_v2.corr()

# 상관관계 매트릭스 시각화
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix_valid_v2, annot=True, cmap='coolwarm')
plt.title('제주 여행 데이터 상관관계 매트릭스', fontproperties=font_prop)
plt.xticks(fontproperties=font_prop)
plt.yticks(fontproperties=font_prop)
plt.show()
# Out:
# C:\Users\it\AppData\Local\Temp\ipykernel_1872\3501665024.py:45: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   numerical_data_v2 = filtered_data.applymap(convert_to_numerical_v2)
# c:\Python\Python310\lib\site-packages\seaborn\utils.py:84: UserWarning: Glyph 51228 (\N{HANGUL SYLLABLE JE}) missing from current font.
#   fig.canvas.draw()
# c:\Python\Python310\lib\site-packages\seaborn\utils.py:84: UserWarning: Glyph 51452 (\N{HANGUL SYLLABLE JU}) missing from current font.
#   fig.canvas.draw()
# c:\Python\Python310\lib\site-packages\seaborn\utils.py:84: UserWarning: Glyph 50668 (\N{HANGUL SYLLABLE YEO}) missing from current font.
#   fig.canvas.draw()
# c:\Python\Python310\lib\site-packages\seaborn\utils.py:84: UserWarning: Glyph 54665 (\N{HANGUL SYLLABLE HAENG}) missing from current font.
#   fig.canvas.draw()
# ...

# %%
import matplotlib
print(matplotlib.get_cachedir())
# Out:
# C:\Users\it\.matplotlib

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import re  # 정규 표현식을 사용하기 위한 모듈

# 폰트 설정
font_path = 'C:/Users/it/Downloads/nanum-all/나눔 글꼴/나눔바른고딕/NanumFontSetup_TTF_BARUNGOTHIC/NanumBarunGothic.ttf'
plt.rcParams['font.family'] = 'NanumBarunGothic'
plt.rcParams['font.sans-serif'] = ['NanumBarunGothic']
plt.rcParams['axes.unicode_minus'] = False

# 파일 경로 설정
file_path = 'C:/Visit_Jeju_BigData_Project/제주 여행 패턴 조사.xlsx'

# 엑셀 파일 읽기
jeju_travel_data = pd.read_excel(file_path)

# 문자열 데이터를 수치형 데이터로 변환하는 함수
def convert_to_numerical_v2(value):
    try:
                # '박' 앞의 숫자만 추출
        match = re.search(r'(\d+)박', value)
        if match:
            return int(match.group(1))
        if isinstance(value, str):
            if ':' in value:  # 시간 값 (예: '10:00')
                hours, minutes = value.split(':')
                return float(hours) + float(minutes) / 60
            elif '시간' in value and '분' in value:  # 지속 시간 (예: '1시간 30분')
                hours, minutes = value.replace('시간', '').replace('분', '').split()
                return float(hours) + float(minutes) / 60
            elif '시간' in value:  # 지속 시간 (예: '1시간')
                return float(value.replace('시간', '').strip())
            elif '곳' in value:  # 횟수 값 (예: '2곳')
                return float(value.replace('곳', '').strip())
            elif '끼' in value:  # 식사 횟수 (예: '3끼')
                return float(value.replace('끼', '').strip())
            elif '분' in value:  # 분 단위 시간 (예: '30분')
                return float(value.replace('분', '').strip()) / 60
        return float(value)
    except (ValueError, TypeError):
        return None

# 데이터 변환 적용
for col in jeju_travel_data.columns[2:18]:  # C열부터 R열:
    jeju_travel_data[col] = jeju_travel_data[col].apply(convert_to_numerical_v2)

# 상관관계 시각화를 위한 서브플롯 생성
fig, axs = plt.subplots(figsize=(16, 16), ncols=3, nrows=5)

# 서브플롯 간 간격 조정
plt.subplots_adjust(wspace=0.5, hspace=0.5)  # 여백 조정

# R열과 C열부터 Q열의 상관관계 시각화
r_column = jeju_travel_data.columns[17]  # R열
for i, col in enumerate(jeju_travel_data.columns[2:17]):  # C열부터 Q열
    row = int(i / 3)
    col_idx = i % 3
    sns.regplot(x=col, y=r_column, data=jeju_travel_data, ax=axs[row][col_idx])

plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import re  # 정규 표현식을 사용하기 위한 모듈

# 폰트 설정
font_path = 'C:/Users/it/Downloads/nanum-all/나눔 글꼴/나눔바른고딕/NanumFontSetup_TTF_BARUNGOTHIC/NanumBarunGothic.ttf'
plt.rcParams['font.family'] = 'NanumBarunGothic'
plt.rcParams['font.sans-serif'] = ['NanumBarunGothic']
plt.rcParams['axes.unicode_minus'] = False

# 파일 경로 설정
file_path = 'C:/Visit_Jeju_BigData_Project/제주 여행 패턴 조사.xlsx'

# 엑셀 파일 읽기
jeju_travel_data = pd.read_excel(file_path)

# 문자열 데이터를 수치형 데이터로 변환하는 함수
def convert_to_numerical_v2(value):
    try:
                # '박' 앞의 숫자만 추출
        match = re.search(r'(\d+)박', value)
        if match:
            return int(match.group(1))
        if isinstance(value, str):
            if ':' in value:  # 시간 값 (예: '10:00')
                hours, minutes = value.split(':')
                return float(hours) + float(minutes) / 60
            elif '시간' in value and '분' in value:  # 지속 시간 (예: '1시간 30분')
                hours, minutes = value.replace('시간', '').replace('분', '').split()
                return float(hours) + float(minutes) / 60
            elif '시간' in value:  # 지속 시간 (예: '1시간')
                return float(value.replace('시간', '').strip())
            elif '곳' in value:  # 횟수 값 (예: '2곳')
                return float(value.replace('곳', '').strip())
            elif '끼' in value:  # 식사 횟수 (예: '3끼')
                return float(value.replace('끼', '').strip())
            elif '분' in value:  # 분 단위 시간 (예: '30분')
                return float(value.replace('분', '').strip()) / 60
        return float(value)
    except (ValueError, TypeError):
        return None

# 데이터 변환 적용
for col in jeju_travel_data.columns[2:18]:  # C열부터 R열:
    jeju_travel_data[col] = jeju_travel_data[col].apply(convert_to_numerical_v2)

# 분석할 열 선택 (C열부터 Q열, R열 포함)
columns_to_analyze = jeju_travel_data.columns[2:17]  # C열부터 Q열
r_column = jeju_travel_data.columns[17]  # R열

# R열과 C-Q열의 상관관계 계산
correlation_with_r = jeju_travel_data[columns_to_analyze].corrwith(jeju_travel_data[r_column])

# 상관관계 시각화
plt.figure(figsize=(10, 8))
sns.barplot(x=correlation_with_r.values, y=correlation_with_r.index)
plt.title('상관관계: R열과 C열부터 Q열', fontproperties=font_prop)
plt.xlabel('상관계수', fontproperties=font_prop)
plt.ylabel('변수', fontproperties=font_prop)
plt.show()

# %% [markdown]
# 각 C열부터 Q열까지의 변수와 '여행 기간 수치' 열과의 상관관계를 계산하고, 상관계수에 따라 정렬하여 영향력이 큰 순서대로 변수를 분류하는 코드를 실행하겠습니다. ​​
#
# 상관관계 분석 결과는 다음과 같습니다:
#
# 1.카페 이동시간으로 적절한 것을 선택해주세요.(*): 0.1097
# 2.한 여행지에서 다음 여행지로 이동 시, 적절한 소요시간에 대해 선택해주세요.(*): 0.0781
# 3.카페에 머무르는 총 시간에 대해 선택해주세요.(*): 0.0584
# 4.한 여행지 당 머무르고 싶은 평균시간에 대해 선택해주세요.(*): 0.0455
# 5.제주 여행 하루 일정을 몇시에 마무리하고 싶은지 선택해주세요.(단, 석식 이후 숙소 도착 시간기준)(*): 0.0361
# 6.식사를 하러갈 때, 이동시간은 얼마가 적당한지 선택해주세요.(*): 0.0336
# 7.(방문객)한 여행지 당 머물렀던 평균시간에 대해 선택해주세요.: 0.0272
# 8.제주 여행을 간다면 하루 일정을 몇시에 시작하고 싶은지 선택해주세요.(단, 숙소 출발 시각기준)(*): 0.0142
# 9.식사(카페 미포함) 소요 시간에 대해 선택해주세요.(*): 0.0089
# 10.하루에 방문하고 싶은 여행지 갯수에 대해 선택해주세요.(카페, 식사는 제외)(*): 0.0072
# 11.제주 여행을 한다면 하루 식사는 몇 번 할지 선택해주세요.(*): 0.0069
